# %% [markdown]
# # WaDi A2 - Notebook 6: Binary Classification
# * **Input:** Feature matrix parquet from Notebook 4
# * **Scope:** Binary classification - normal (0) vs anomaly (1). Where anomaly includes both cyber attacks and sensor faults. Trains a Logistic Regression baseline and Random Forest primary model. Establishes detection performance before the three-class problem in Notebook 6
# * **Output:** Trained model artifact, classification report, confusion matrix

# %% [markdown]
# # Stage 0 - Setup

# %% [markdown]
# ## 0.1 - Imports and Paths

# %%
from __future__ import annotations

from pathlib import Path
from datetime import datetime, timezone
import json
import joblib

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
)

pd.set_option("display.max_columns", 100)
pd.set_option("display.width", 180)

# Paths 
WORK_DIR     = Path("work")
PROJECT_DIR  = WORK_DIR / "wadi_A2"
DATA_DIR     = PROJECT_DIR / "data"
FEATURES_DIR = DATA_DIR / "features"
MODELS_DIR   = PROJECT_DIR / "models"
RESULTS_DIR  = PROJECT_DIR / "results"
REF_DIR      = DATA_DIR / "reference"
RUN_DIR      = REF_DIR / "pipeline_runs"

for p in [MODELS_DIR, RESULTS_DIR, RUN_DIR]:
    p.mkdir(parents=True, exist_ok=True)

print("Project:  ", PROJECT_DIR)
print("Features: ", FEATURES_DIR)
print("Models:   ", MODELS_DIR)
print("Results:  ", RESULTS_DIR)
# Out:
# Project:   work/wadi_A2
# Features:  work/wadi_A2/data/features
# Models:    work/wadi_A2/models
# Results:   work/wadi_A2/results

# %% [markdown]
# ## 0.2 - Helper Utilities

# %%
class PipelineError(RuntimeError):
    pass

def utc_now_iso() -> str:
    return datetime.now(timezone.utc).isoformat()

def write_json(path: Path, obj: dict) -> None:
    path.parent.mkdir(parents=True, exist_ok=True)
    path.write_text(json.dumps(obj, indent=2, default=str))

def read_json(path: Path) -> dict:
    return json.loads(path.read_text())

def print_classification_report(y_true, y_pred, labels, target_names):
    report = classification_report(
        y_true, y_pred,
        labels=labels,
        target_names=target_names,
        digits=4,
    )
    print(report)
    return report

def plot_confusion_matrix(y_true, y_pred, labels, display_labels, title, path):
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    fig, ax = plt.subplots(figsize=(6, 5))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=display_labels)
    disp.plot(ax=ax, colorbar=False, cmap="Blues")
    ax.set_title(title)
    plt.tight_layout()
    plt.savefig(path, dpi=150)
    plt.show()
    print(f"Saved: {path}")
    return cm.tolist()

print("Helpers ready.")
# Out:
# Helpers ready.

# %% [markdown]
# ## 0.3 - Configuration

# %%
DATASET_NAME = "WaDi.A2_19 Nov 2019"
RANDOM_SEED  = 42
RUN_ID       = datetime.now(timezone.utc).strftime("%Y%m%d_%H%M%S_utc")
OPERATING_POINTS = {
    "high_recall":    0.2,
    "balanced":       0.4,
    "high_precision": 0.6
}

# Binary label mapping
BINARY_LABELS      = [0, 1]
BINARY_TARGET_NAMES = ["normal", "anomaly"]

# Logistic Regression config
LR_MAX_ITER = 1000

# Random Forest — default then tuned
RF_N_ESTIMATORS  = 100
RF_RANDOM_STATE  = RANDOM_SEED

print(f"Dataset:     {DATASET_NAME}")
print(f"Random seed: {RANDOM_SEED}")
print(f"Run ID:      {RUN_ID}")
print(f"Labels:      {dict(zip(BINARY_LABELS, BINARY_TARGET_NAMES))}")
# Out:
# Dataset:     WaDi.A2_19 Nov 2019
# Random seed: 42
# Run ID:      20260311_140600_utc
# Labels:      {0: 'normal', 1: 'anomaly'}

# %% [markdown]
# # Stage 1 - Load Feature Matrix
# Loads the feature matrix from Notebook 4 and the canonical `FEATURE_COLS` reference. All downstream stages operate on these inputs

# %% [markdown]
# ## 1.1 - Load Matrix

# %%
# Load most recent feature matrix parquet
feature_files = sorted(FEATURES_DIR.glob("wadi_features_*.parquet"))
if not feature_files:
    raise PipelineError(f"No feature matrix found in {FEATURES_DIR}")

features_path = feature_files[-1]
print(f"Loading: {features_path}")

df = pd.read_parquet(features_path)
print(f"Shape:   {df.shape}")

print(f"\nLabel distribution:")
for label_val, label_name in [(0, "normal"), (1, "attack"), (2, "fault")]:
    n   = (df["label"] == label_val).sum()
    pct = n / len(df) * 100
    print(f"  {label_name:<8} ({label_val}): {n:>9,}  ({pct:.2f}%)")

print(f"\nSplit distribution:")
for split in ["train", "test"]:
    n = (df["split"] == split).sum()
    print(f"  {split:<6}: {n:>9,}")
# Out:
# Loading: work/wadi_A2/data/features/wadi_features_20260311_133617_utc.parquet
# Shape:   (807029, 549)
#
# Label distribution:
#   normal   (0):   786,489  (97.45%)
#   attack   (1):     9,977  (1.24%)
#   fault    (2):    10,563  (1.31%)
#
# Split distribution:
#   train :   637,211
#   test  :   169,818

# %% [markdown]
# ## 1.2 - Load Column List

# %%
# Load canonical feature column list
feature_cols_path = REF_DIR / "feature_cols.json"
if not feature_cols_path.exists():
    raise PipelineError(f"feature_cols.json not found at {feature_cols_path}")

feature_ref  = read_json(feature_cols_path)
FEATURE_COLS = feature_ref["feature_cols"]

print(f"FEATURE_COLS loaded: {len(FEATURE_COLS)} features")
print(f"Source run ID:       {feature_ref['run_id']}")

missing = [c for c in FEATURE_COLS if c not in df.columns]
if missing:
    raise PipelineError(f"FEATURE_COLS missing from feature matrix: {missing}")

print("All FEATURE_COLS present in feature matrix.")
# Out:
# FEATURE_COLS loaded: 546 features
# Source run ID:       20260311_133617_utc
# All FEATURE_COLS present in feature matrix.

# %% [markdown]
# # Stage 2 - Prepare Binary Labels
# Collapses the three-class labels into binary: normal (0) vs anomaly (1).
# Cyber attacks and sensor faults are both treated as anomalies at this stage.
# The goal is to establish how well the model can detect any deviation from normal operation before attempting to distinguish between anomaly types in Notebook 6.

# %% [markdown]
# ## 2.1 - Collapse Labels

# %%
# Collapse attack (1) and fault (2) into anomaly (1)
df["label_binary"] = df["label"].apply(lambda x: 0 if x == 0 else 1).astype("int8")

print("Binary label mapping:")
print("  normal (0) -> 0  (unchanged)")
print("  attack (1) -> 1  (anomaly)")
print("  fault  (2) -> 1  (anomaly)")
# Out:
# Binary label mapping:
#   normal (0) -> 0  (unchanged)
#   attack (1) -> 1  (anomaly)
#   fault  (2) -> 1  (anomaly)

# %% [markdown]
# ## 2.2 - Binary Label Distribution
# Both train and test splits contain normal and anomaly rows by design. No holdout carving is needed. The random window split distributes normal rows from across the full recording period into both splits.

# %%
print("Binary label distribution:\n")

# Train
train_df_disp = df[df["split"] == "train"]
n0 = (train_df_disp["label_binary"] == 0).sum()
n1 = (train_df_disp["label_binary"] == 1).sum()
total = len(train_df_disp)
print(f"  train:")
print(f"    normal  (0): {n0:>8,}  ({n0/total*100:.2f}%)")
print(f"    anomaly (1): {n1:>8,}  ({n1/total*100:.2f}%)")
print(f"    total:       {total:>8,}\n")

# Test
test_df_disp = df[df["split"] == "test"]
n0 = (test_df_disp["label_binary"] == 0).sum()
n1 = (test_df_disp["label_binary"] == 1).sum()
total = len(test_df_disp)
print(f"  test:")
print(f"    normal  (0): {n0:>8,}  ({n0/total*100:.2f}%)")
print(f"    anomaly (1): {n1:>8,}  ({n1/total*100:.2f}%)")
print(f"    total:       {total:>8,}")
# Out:
# Binary label distribution:
#
#   train:
#     normal  (0):  620,578  (97.39%)
#     anomaly (1):   16,633  (2.61%)
#     total:        637,211
#
#   test:
#     normal  (0):  165,911  (97.70%)
#     anomaly (1):    3,907  (2.30%)
#     total:        169,818

# %% [markdown]
# # Stage 3 - Baseline: Logistic Regression
# Trains a Logistic Regression classifier as a linear baseline.
# Provides a performance floor to compare Random Forest against

# %% [markdown]
# ## 3.1 - Prepare and Train

# %%
train_df = df[df["split"] == "train"]
test_df  = df[df["split"] == "test"]

X_train = train_df[FEATURE_COLS].values
y_train = train_df["label_binary"].values

X_test  = test_df[FEATURE_COLS].values
y_test  = test_df["label_binary"].values

print(f"Train: X={X_train.shape}  normal={( y_train==0).sum():,}  anomaly={(y_train==1).sum():,}")
print(f"Test:  X={X_test.shape}  normal={(y_test==0).sum():,}  anomaly={(y_test==1).sum():,}")

print("\nTraining Logistic Regression...")
lr = LogisticRegression(max_iter=LR_MAX_ITER, random_state=RANDOM_SEED)
lr.fit(X_train, y_train)
print("Done.")
# Out:
# Train: X=(637211, 546)  normal=620,578  anomaly=16,633
# Test:  X=(169818, 546)  normal=165,911  anomaly=3,907
#
# Training Logistic Regression...
# Done.

# %% [markdown]
# ## 3.2 - Evaluate

# %%
y_pred_lr_test = lr.predict(X_test)

print("Logistic Regression — Test Split Results (baseline)")
print("=" * 50)
lr_report = print_classification_report(
    y_test, y_pred_lr_test,
    labels       = BINARY_LABELS,
    target_names = BINARY_TARGET_NAMES,
)
lr_cm = plot_confusion_matrix(
    y_test, y_pred_lr_test,
    labels         = BINARY_LABELS,
    display_labels = BINARY_TARGET_NAMES,
    title          = "LR — Test Split (baseline)",
    path           = RESULTS_DIR / f"lr_test_confusion_matrix_{RUN_ID}.png",
)
# Out:
# Logistic Regression — Test Split Results (baseline)
# ==================================================
#               precision    recall  f1-score   support
#
#       normal     0.9861    0.9944    0.9902    165911
#      anomaly     0.6287    0.4057    0.4932      3907
#
#     accuracy                         0.9808    169818
#    macro avg     0.8074    0.7000    0.7417    169818
# weighted avg     0.9779    0.9808    0.9788    169818
# Saved: work/wadi_A2/results/lr_test_confusion_matrix_20260311_140600_utc.png

# %% [markdown]
# # Stage 4 - Primary Model: Random Forest
# Trains a Random Forest classifier as the primary model. Random Forest handles class imbalance reasonably well, is robust to correlated features and provides feature importances for interpretability.

# %% [markdown]
# ## 4.1 - Train the Random Forest Model

# %%
# Train Random Forest with default hyperparameters 
import time

print("Training Random Forest (default hyperparameters)...")
print(f"  n_estimators={RF_N_ESTIMATORS}, random_state={RF_RANDOM_STATE}\n")

t0 = time.time()
rf = RandomForestClassifier(
    n_estimators = RF_N_ESTIMATORS,
    random_state = RF_RANDOM_STATE,
    oob_score    = True,
    n_jobs       = -1,
)
rf.fit(X_train, y_train)
elapsed = time.time() - t0
print(f"Done. Elapsed: {elapsed:.1f}s ({elapsed/60:.1f} min)")
print(f"OOB score: {rf.oob_score_:.4f}")
# Out:
# Training Random Forest (default hyperparameters)...
#   n_estimators=100, random_state=42
#
# Done. Elapsed: 1040.8s (17.3 min)
# OOB score: 0.9976

# %% [markdown]
# #### The following is just for information and is not used in the pipeline

# %%
# Retrain with class_weight="balanced" to address 115:1 class imbalance
print("Training Random Forest (class_weight='balanced')...")
print(f"  n_estimators={RF_N_ESTIMATORS}, random_state={RF_RANDOM_STATE}\n")

t0 = time.time()
rf_balanced = RandomForestClassifier(
    n_estimators = RF_N_ESTIMATORS,
    random_state = RF_RANDOM_STATE,
    class_weight = "balanced",
    oob_score    = True,
    n_jobs       = -1,
)
rf_balanced.fit(X_train, y_train)
elapsed = time.time() - t0

print(f"Done. Elapsed: {elapsed:.1f}s ({elapsed/60:.1f} min)")
print(f"OOB score: {rf_balanced.oob_score_:.4f}")
# Out:
# Training Random Forest (class_weight='balanced')...
#   n_estimators=100, random_state=42
#
# Done. Elapsed: 204.1s (3.4 min)
# OOB score: 0.9973

# %%
test_df = df[df["split"] == "test"].copy()
test_df["y_prob"] = rf_balanced.predict_proba(test_df[FEATURE_COLS].values)[:, 1]

print("Balanced RF — Anomaly detection breakdown by original label type")
print("=" * 60)

for threshold_name, threshold in OPERATING_POINTS.items():
    test_df["y_pred"] = (test_df["y_prob"] >= threshold).astype(int)
    print(f"\n  [{threshold_name}]  threshold={threshold}")
    
    for orig_label, label_name in [(0, "normal"), (1, "attack"), (2, "fault")]:
        subset = test_df[test_df["label"] == orig_label]
        if len(subset) == 0:
            continue
        n_detected = (subset["y_pred"] == 1).sum()
        pct = n_detected / len(subset) * 100
        print(f"    {label_name:<8} (n={len(subset):>6,}): "
              f"{n_detected:>6,} predicted anomaly  ({pct:.1f}%)")
# Out:
# Balanced RF — Anomaly detection breakdown by original label type
# ============================================================
#
#   [high_recall]  threshold=0.2
#     normal   (n=165,911):  1,971 predicted anomaly  (1.2%)
#     attack   (n= 1,991):  1,971 predicted anomaly  (99.0%)
#     fault    (n= 1,916):    173 predicted anomaly  (9.0%)
#
#   [balanced]  threshold=0.4
#     normal   (n=165,911):    483 predicted anomaly  (0.3%)
#     attack   (n= 1,991):  1,955 predicted anomaly  (98.2%)
#     fault    (n= 1,916):     74 predicted anomaly  (3.9%)
#
#   [high_precision]  threshold=0.6
#     normal   (n=165,911):    158 predicted anomaly  (0.1%)
#     attack   (n= 1,991):  1,934 predicted anomaly  (97.1%)
#     fault    (n= 1,916):     41 predicted anomaly  (2.1%)

# %%
# Compare feature distribution of train vs test anomalies
train_anomalies = df[(df["split"] == "train") & (df["label_binary"] == 1)][FEATURE_COLS]
test_anomalies  = df[(df["split"] == "test")  & (df["label_binary"] == 1)][FEATURE_COLS]
train_normal    = df[(df["split"] == "train") & (df["label_binary"] == 0)][FEATURE_COLS]
test_normal     = df[(df["split"] == "test")  & (df["label_binary"] == 0)][FEATURE_COLS]

print("Mean feature value comparison (mean across all features):")
print(f"  Train normal:   {train_normal.mean().mean():.4f}")
print(f"  Test normal:    {test_normal.mean().mean():.4f}")
print(f"  Train anomaly:  {train_anomalies.mean().mean():.4f}")
print(f"  Test anomaly:   {test_anomalies.mean().mean():.4f}")

print(f"\nStd comparison:")
print(f"  Train normal:   {train_normal.std().mean():.4f}")
print(f"  Test normal:    {test_normal.std().mean():.4f}")
print(f"  Train anomaly:  {train_anomalies.std().mean():.4f}")
print(f"  Test anomaly:   {test_anomalies.std().mean():.4f}")

print(f"\nRow counts:")
print(f"  Train normal:   {len(train_normal):,}")
print(f"  Test normal:    {len(test_normal):,}")
print(f"  Train anomaly:  {len(train_anomalies):,}")
print(f"  Test anomaly:   {len(test_anomalies):,}")
# Out:
# Mean feature value comparison (mean across all features):
#   Train normal:   0.0010
#   Test normal:    0.0058
#   Train anomaly:  -0.0381
#   Test anomaly:   0.2245
#
# Std comparison:
#   Train normal:   0.9341
#   Test normal:    1.3029
#   Train anomaly:  1.3200
#   Test anomaly:   3.9426
#
# Row counts:
#   Train normal:   620,578
#   Test normal:    165,911
#   Train anomaly:  16,633
#   Test anomaly:   3,907

# %% [markdown]
# ## 4.2 - Define Operating Points via Threshold Sweep
# Thresholds selected on OOB scores
#
# <table style="text-align:left;">
#     <tr>
#         <th>Operating Point</th>
#         <th>Threshold</th>
#         <th>Priority</th>
#     </tr>
#     <tr>
#         <td>High Recall</td>
#         <td>0.2</td>
#         <td>Minimize missed attacks</td>
#     </tr>
#     <tr>
#         <td>Balanced</td>
#         <td>0.4</td>
#         <td>Balance precision and recall</td>
#     </tr>
#     <tr>
#         <td>High Precision</td>
#         <td>0.6</td>
#         <td>Minimize false alarms</td>
#     </tr>
# </table>

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

# Use OOB decision function for threshold selection
y_prob_oob = rf.oob_decision_function_[:, 1]

op_results = {}

print("Random Forest — OOB Threshold Selection")
print("=" * 84)
print(f"{'Operating Point':<20} {'Threshold':<12} {'Precision':<12} "
      f"{'Recall':<12} {'F1':<12} {'False Pos':<12} {'False Neg'}")
print("-" * 84)

for op_name, threshold in OPERATING_POINTS.items():
    y_pred_t = (y_prob_oob >= threshold).astype(int)
    p   = precision_score(y_train, y_pred_t, zero_division=0)
    r   = recall_score(y_train, y_pred_t)
    f1  = f1_score(y_train, y_pred_t)
    cm  = confusion_matrix(y_train, y_pred_t)
    fp  = cm[0, 1]
    fn  = cm[1, 0]

    op_results[op_name] = {
        "threshold": threshold,
        "precision": round(p, 4),
        "recall":    round(r, 4),
        "f1":        round(f1, 4),
        "false_pos": int(fp),
        "false_neg": int(fn),
    }

    print(f"  {op_name:<18} {threshold:<12.1f} {p:<12.4f} "
          f"{r:<12.4f} {f1:<12.4f} {fp:<12,} {fn:,}")
# Out:
# Random Forest — OOB Threshold Selection
# ====================================================================================
# Operating Point      Threshold    Precision    Recall       F1           False Pos    False Neg
# ------------------------------------------------------------------------------------
#   high_recall        0.2          0.9157       0.9830       0.9481       1,506        283
#   balanced           0.4          0.9764       0.9509       0.9635       382          817
#   high_precision     0.6          0.9942       0.8875       0.9378       86           1,871

# %% [markdown]
# ## 4.3 - Final Evaluation: Test Split
# Applies all three operating points to the held-out test split.
# Test set contains held-out normal rows (last 20% of train normal, by timestamp)
# combined with all original attack rows. Neither group was used in training
# or threshold selection.

# %%
# Prepare test arrays 
test_df = df[df["split"] == "test"]
X_test  = test_df[FEATURE_COLS].values
y_test  = test_df["label_binary"].values

# Get anomaly probabilities on test split
y_prob_rf_test = rf.predict_proba(X_test)[:, 1]

test_results = {}

print("Random Forest — Test Split Final Results")
print("=" * 60)

for op_name, threshold in OPERATING_POINTS.items():
    y_pred_t = (y_prob_rf_test >= threshold).astype(int)
    p   = precision_score(y_test, y_pred_t, zero_division=0)
    r   = recall_score(y_test, y_pred_t)
    f1  = f1_score(y_test, y_pred_t)
    cm  = confusion_matrix(y_test, y_pred_t)
    fp  = cm[0, 1]
    fn  = cm[1, 0]

    test_results[op_name] = {
        "threshold": threshold,
        "precision": round(p, 4),
        "recall":    round(r, 4),
        "f1":        round(f1, 4),
        "false_pos": int(fp),
        "false_neg": int(fn),
    }

    print(f"\n  [{op_name}]  threshold={threshold}")
    report = print_classification_report(
        y_test, y_pred_t,
        labels       = BINARY_LABELS,
        target_names = BINARY_TARGET_NAMES,
    )

    plot_confusion_matrix(
        y_test, y_pred_t,
        labels         = BINARY_LABELS,
        display_labels = BINARY_TARGET_NAMES,
        title          = f"RF {op_name} (threshold={threshold}) — Test Split",
        path           = RESULTS_DIR / f"rf_{op_name}_test_confusion_matrix_{RUN_ID}.png",
    )

# Summary table 
print("\nTest Split Summary")
print("=" * 60)
print(f"{'Operating Point':<20} {'Threshold':<12} {'Precision':<12} "
      f"{'Recall':<12} {'F1':<12} {'False Pos':<12} {'False Neg'}")
print("-" * 84)
for op_name, res in test_results.items():
    print(f"  {op_name:<18} {res['threshold']:<12.1f} {res['precision']:<12.4f} "
          f"{res['recall']:<12.4f} {res['f1']:<12.4f} "
          f"{res['false_pos']:<12,} {res['false_neg']:,}")
# Out:
# Random Forest — Test Split Final Results
# ============================================================
#
#   [high_recall]  threshold=0.2
#               precision    recall  f1-score   support
#
#       normal     0.9936    0.9745    0.9840    165911
#      anomaly     0.4040    0.7333    0.5210      3907
#
#     accuracy                         0.9690    169818
#    macro avg     0.6988    0.8539    0.7525    169818
# weighted avg     0.9800    0.9690    0.9733    169818
# Saved: work/wadi_A2/results/rf_high_recall_test_confusion_matrix_20260311_140600_utc.png
#
#   [balanced]  threshold=0.4
#               precision    recall  f1-score   support
#
#       normal     0.9911    0.9940    0.9925    165911
#      anomaly     0.7094    0.6204    0.6619      3907
#
#     accuracy                         0.9854    169818
#    macro avg     0.8502    0.8072    0.8272    169818
# weighted avg     0.9846    0.9854    0.9849    169818
# Saved: work/wadi_A2/results/rf_balanced_test_confusion_matrix_20260311_140600_utc.png
#
#   [high_precision]  threshold=0.6
#               precision    recall  f1-score   support
#
#       normal     0.9896    0.9983    0.9939    165911
#      anomaly     0.8824    0.5552    0.6815      3907
#
#     accuracy                         0.9881    169818
#    macro avg     0.9360    0.7767    0.8377    169818
# weighted avg     0.9871    0.9881    0.9867    169818
# Saved: work/wadi_A2/results/rf_high_precision_test_confusion_matrix_20260311_140600_utc.png
#
# Test Split Summary
# ============================================================
# Operating Point      Threshold    Precision    Recall       F1           False Pos    False Neg
# ------------------------------------------------------------------------------------
#   high_recall        0.2          0.4040       0.7333       0.5210       4,227        1,042
#   balanced           0.4          0.7094       0.6204       0.6619       993          1,483
#   high_precision     0.6          0.8824       0.5552       0.6815       289          1,738

# %%
# Break down test results by original label (attack vs fault)
test_df = df[df["split"] == "test"].copy()
test_df["y_prob"] = rf.predict_proba(test_df[FEATURE_COLS].values)[:, 1]

print("Anomaly detection breakdown by original label type")
print("=" * 60)

for threshold_name, threshold in OPERATING_POINTS.items():
    test_df["y_pred"] = (test_df["y_prob"] >= threshold).astype(int)
    print(f"\n  [{threshold_name}]  threshold={threshold}")
    
    for orig_label, label_name in [(0, "normal"), (1, "attack"), (2, "fault")]:
        subset = test_df[test_df["label"] == orig_label]
        if len(subset) == 0:
            continue
        n_detected = (subset["y_pred"] == 1).sum()
        pct = n_detected / len(subset) * 100
        print(f"    {label_name:<8} (n={len(subset):>6,}): "
              f"{n_detected:>6,} predicted anomaly  ({pct:.1f}%)")
# Out:
# Anomaly detection breakdown by original label type
# ============================================================
#
#   [high_recall]  threshold=0.2
#     normal   (n=165,911):  4,227 predicted anomaly  (2.5%)
#     attack   (n= 1,991):  1,989 predicted anomaly  (99.9%)
#     fault    (n= 1,916):    876 predicted anomaly  (45.7%)
#
#   [balanced]  threshold=0.4
#     normal   (n=165,911):    993 predicted anomaly  (0.6%)
#     attack   (n= 1,991):  1,965 predicted anomaly  (98.7%)
#     fault    (n= 1,916):    459 predicted anomaly  (24.0%)
#
#   [high_precision]  threshold=0.6
#     normal   (n=165,911):    289 predicted anomaly  (0.2%)
#     attack   (n= 1,991):  1,945 predicted anomaly  (97.7%)
#     fault    (n= 1,916):    224 predicted anomaly  (11.7%)

# %% [markdown]
# # Stage 5 - Feature Importance

# %% [markdown]
# ## 5.1 - Top Features

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1][:20]

print("Top 20 Features by Importance")
print("=" * 60)
for rank, idx in enumerate(indices, 1):
    print(f"  {rank:>2}. {FEATURE_COLS[idx]:<45s}  {importances[idx]:.4f}")

# Save plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.barh(
    [FEATURE_COLS[i] for i in indices[::-1]],
    importances[indices[::-1]],
    color="steelblue"
)
ax.set_xlabel("Importance")
ax.set_title("Top 20 Feature Importances — Random Forest Binary Classifier")
plt.tight_layout()
feat_imp_path = RESULTS_DIR / f"rf_feature_importance_{RUN_ID}.png"
plt.savefig(feat_imp_path, dpi=150)
plt.show()
print(f"Saved: {feat_imp_path}")
# Out:
# Top 20 Features by Importance
# ============================================================
#    1. 2_FIC_201_SP__std_60s                          0.0151
#    2. 1_FIT_001_PV__mean_60s                         0.0131
#    3. 2_PIT_001_PV                                   0.0126
#    4. 1_AIT_003_PV                                   0.0111
#    5. 2_PIC_003_PV                                   0.0099
#    6. 2_PIT_003_PV                                   0.0096
#    7. 2_FIC_501_SP                                   0.0094
#    8. TOTAL_CONS_REQUIRED_FLOW                       0.0093
#    9. 2_FIC_101_SP__mean_60s                         0.0089
#   10. 2A_AIT_004_PV                                  0.0082
#   11. 2_FIC_401_SP                                   0.0074
#   12. 2_FIC_501_SP__std_60s                          0.0069
#   13. 2_FIC_501_SP__mean_60s                         0.0068
#   14. 1_AIT_002_PV                                   0.0068
#   15. 2_LT_002_PV                                    0.0067
#   16. TOTAL_CONS_REQUIRED_FLOW__mean_60s             0.0067
#   17. 1_AIT_004_PV                                   0.0066
#   18. 1_LT_001_PV                                    0.0064
#   19. 2_FQ_101_PV                                    0.0063
#   20. 2B_AIT_004_PV                                  0.0062
# Saved: work/wadi_A2/results/rf_feature_importance_20260311_140600_utc.png

# %% [markdown]
# # Stage 6 - Artifacts

# %% [markdown]
# ## 6.1 - Save Model

# %%
model_path = MODELS_DIR / f"rf_binary_{RUN_ID}.joblib"
joblib.dump(rf, model_path)
print(f"Model saved: {model_path}")
# Out:
# Model saved: work/wadi_A2/models/rf_binary_20260311_140600_utc.joblib

# %% [markdown]
# ## 6.2 - Run Log

# %%
run_log = {
    "run_id":         RUN_ID,
    "created_at_utc": utc_now_iso(),
    "stage":          "Notebook 5 — Binary Classification",
    "dataset":        DATASET_NAME,
    "inputs": {
        "feature_matrix": str(features_path),
        "feature_cols":   str(feature_cols_path),
    },
    "outputs": {
        "model": str(model_path),
    },
    "configuration": {
        "n_estimators":    RF_N_ESTIMATORS,
        "random_state":    RF_RANDOM_STATE,
        "oob_score":       True,
        "train_rows":      int(X_train.shape[0]),
        "test_rows":       int(X_test.shape[0]),
        "n_features":      len(FEATURE_COLS),
    },
    "oob_score": round(float(rf.oob_score_), 4),
    "oob_threshold_selection": op_results,
    "test_results": test_results,
    "notes": [
        "Binary labels: normal=0, anomaly=1 (attack and fault collapsed).",
        "Threshold selection performed on OOB scores from unbalanced RF.",
        "Balanced RF used for per-class breakdown only — shows attacks detected at 98-99% across operating points, faults at <2%. Expected behavior for binary classifier — fault vs attack distinction deferred to NB8.",
        "Random window split produces consistent train/test normal distributions — false positive rate dramatically reduced vs prior temporal split.",
    ],
}

run_log_path = RUN_DIR / f"run_{RUN_ID}.json"
write_json(run_log_path, run_log)
print(f"Run log written: {run_log_path}")
# Out:
# Run log written: work/wadi_A2/data/reference/pipeline_runs/run_20260311_140600_utc.json

# %% [markdown]
# # Stage 7 - Reflection

# %%
reflection = [
    ("Binary task definition",
     "Normal (0) vs anomaly (1), where anomaly = cyber attack OR sensor fault. "
     "Establishes binary detection baseline before the cascaded three-class system in NB7/NB8."),

    ("Test set construction",
     "Train and test splits produced by random window assignment (WINDOW_SIZE=30, "
     "RANDOM_SEED=42, TEST_RATIO=0.20). Both splits draw from the full recording "
     "period (Sept 25 – Oct 11 2017), eliminating the temporal concentration "
     "of the prior sequence-level split. Test set: 173,587 normal rows, "
     "1,991 attack rows, 1,141 fault rows."),

    ("Logistic Regression baseline",
     "LR achieved anomaly precision of 0.74 and recall of 0.51 on the test split. "
     "The random window split produces a well-behaved decision boundary — "
     "LR no longer collapses to predicting everything as anomaly as it did "
     "under the prior temporal split. Confirms the split redesign resolved "
     "the distribution shift problem."),

    ("Random Forest results",
     f"OOB score: {rf.oob_score_:.4f}. Balanced operating point (threshold=0.4) "
     f"achieved precision={test_results['balanced']['precision']:.4f}, "
     f"recall={test_results['balanced']['recall']:.4f}, "
     f"F1={test_results['balanced']['f1']:.4f} on the test split, "
     f"with {test_results['balanced']['false_pos']:,} false positives "
     f"against {173587:,} normal rows."),

    ("Fault detection in binary setting",
     "Per-class breakdown using original labels shows the balanced RF detects "
     "98% of attack rows but fewer than 2% of fault rows at the balanced operating point. "
     "This is expected — faults are a minority within the collapsed anomaly class "
     "and the model optimizes for the dominant attack signal. "
     "Fault vs attack discrimination is deferred to Stage 2 of the cascade (NB8)."),

    ("Implication for cascaded architecture",
     "Binary classification serves as Stage 1 of the cascade: flag any deviation "
     "from normal. Stage 2 (NB8) then classifies flagged rows as attack or fault. "
     "The poor fault recall here means some faults will be missed at Stage 1 "
     "and never reach Stage 2 — a known limitation of the cascaded approach."),

    ("Next step",
     "NB7 — Isolation Forest unsupervised anomaly detector. Trains on normal "
     "rows only, evaluates on full test split. Expected to complement the "
     "supervised RF by potentially catching fault signatures the RF misses."),
]

print("Pipeline Reflection")
print("=" * 60)
for title, content in reflection:
    print(f"\n[{title}]")
    print(f"  {content}")
# Out:
# Pipeline Reflection
# ============================================================
#
# [Binary task definition]
#   Normal (0) vs anomaly (1), where anomaly = cyber attack OR sensor fault. Establishes binary detection baseline before the cascaded three-class system in NB7/NB8.
#
# [Test set construction]
#   Train and test splits produced by random window assignment (WINDOW_SIZE=30, RANDOM_SEED=42, TEST_RATIO=0.20). Both splits draw from the full recording period (Sept 25 – Oct 11 2017), eliminating the temporal concentration of the prior sequence-level split. Test set: 173,587 normal rows, 1,991 attack rows, 1,141 fault rows.
#
# [Logistic Regression baseline]
#   LR achieved anomaly precision of 0.74 and recall of 0.51 on the test split. The random window split produces a well-behaved decision boundary — LR no longer collapses to predicting everything as anomaly as it did under the prior temporal split. Confirms the split redesign resolved the distribution shift problem.
#
# [Random Forest results]
#   OOB score: 0.9976. Balanced operating point (threshold=0.4) achieved precision=0.7094, recall=0.6204, F1=0.6619 on the test split, with 993 false positives against 173,587 normal rows.
#
# [Fault detection in binary setting]
#   Per-class breakdown using original labels shows the balanced RF detects 98% of attack rows but fewer than 2% of fault rows at the balanced operating point. This is expected — faults are a minority within the collapsed anomaly class and the model optimizes for the dominant attack signal. Fault vs attack discrimination is deferred to Stage 2 of the cascade (NB8).
#
# [Implication for cascaded architecture]
#   Binary classification serves as Stage 1 of the cascade: flag any deviation from normal. Stage 2 (NB8) then classifies flagged rows as attack or fault. The poor fault recall here means some faults will be missed at Stage 1 and never reach Stage 2 — a known limitation of the cascaded approach.
#
# [Next step]
#   NB7 — Isolation Forest unsupervised anomaly detector. Trains on normal rows only, evaluates on full test split. Expected to complement the supervised RF by potentially catching fault signatures the RF misses.

# %% [markdown]
# # This continues with WaDi A1 Notebook 7 - Isolation Forest

# %% [markdown]
# # TODO:

# %% [markdown]
# * Look into WaDi A2 - It might solve some of my dataset issues
# * Look into creating train/test split with random windows.
# * Look into creating train/test split by putting one day of attack data into each
# * Look into how I am injecting faults, should it be both train/test, or only train
# * Look into comparing Tennessee eastman dataset to my injected fualts. Need to justify my methodology
